# %% [markdown]
# # Посевы 1го января

# %%
import pandas as pd
from IPython.display import Image

# %%
data = [
    {
        'index': 1,
        'Род':'ASTROPHYTUM',
        'Вид':'crassispinum',
        'Количество семян': 13,
        'Номер в каталоге': 51.83,
        'Источник': 'Кактус клуб'
    },
    {
        'index':2,
        'Род':'AUSTROCACTUS',
        'Вид': 'patagonicus',
        'Место произрастания': 'VG-1406',
        'Количество семян' : 15,
        'Номер в каталоге': 70.03,
        'Источник': 'Кактус клуб'
    },
    {
        'index':3,
        'Род':'AUSTROCACTUS',
        'Вид': 'subandinus',
        'Место произрастания': 'SAR 6824 "Los Houes"',
        'Количество семян' : 10,
        'Источник': 'Подарок немцев'
    },
    {
        'index':4,
        'Род':'ECHINOCACTUS',
        'Вид': 'grusonii',
        'Количество семян' : 27,
        'Номер в каталоге': 175.1,
        'Источник': 'Кактус клуб'
    },
    {
        'index':5,
        'Род':'ECHINOCACTUS',
        'Вид': 'horizontalonius',
        'Количество семян' : 12,
        'Номер в каталоге': 176.15,
        'Источник': 'Кактус клуб'
    },
    {
        'index':6,
        'Род':'FRAILEA',
        'Вид': 'asterioides',
        'Место произрастания': 'VG-1425, Topador, Uruguay',
        'Количество семян' : 12,
        'Номер в каталоге': 309.0989,
        'Источник': 'Кактус клуб'
    },
    {
        'index':7,
        'Род':'ECHINOFOSSULOCACTUS',
        'Вид': 'multicostatus',
        'Место произрастания': 'HB 32',
        'Количество семян' : 10,
        'Номер в каталоге': 235.353,
        'Источник': 'Кактус клуб'
    },
    {
        'index':8,
        'Род':'TURBINICARPUS',
        'Вид': 'alonsoi',
        'Количество семян' : 17,
        'Номер в каталоге': 1081.17,
        'Источник': 'Кактус клуб'
    },
    {
        'index':9,
        'Род':'GYMNOCALYCIUM ',
        'Вид': 'esperanzae',
        'Место произрастания': 'VG-1242, Corral de Isaac, La Rioja',
        'Количество семян' : 24,
        'Номер в каталоге': 350.963,
        'Источник': 'Кактус клуб'
    },
    {
        'index':10,
        'Род':'MAMMILLARIA',
        'Вид': 'blossfeldiana',
        'Количество семян' : 17,
        'Номер в каталоге': 596,
        'Источник': 'Кактус клуб'
    },
    {
        'index':11,
        'Род':'LOBIVIA',
        'Вид': 'famatimensis',
        'Место произрастания': 'VG-678, Sa de Famatina, La Rioja',
        'Количество семян' : 12,
        'Номер в каталоге': 474.14,
        'Источник': 'Кактус клуб'
    },
    {
        'index':12,
        'Род':'LOBIVIA',
        'Вид': 'jajoana',
        'Количество семян' : 11,
        'Номер в каталоге': 482.41,
        'Источник': 'Кактус клуб'
    },
    {
        'index':13,
        'Род':'MAMMILLARIA',
        'Вид': 'saboae ssp. roczekii',
        'Количество семян' : 6,
        'Номер в каталоге': 699.8,
        'Источник': 'Кактус клуб'
    },
    {
        'index':14,
        'Род':'NEOCHILENIA',
        'Вид': 'heinrichiana',
        'Количество семян' : 13,
        'Источник': 'Свои'
    },
    {
        'index':15,
        'Род':'ERIOSYCE',
        'Вид': 'curvispina',
        'Место произрастания': 'SAR 6732, Farellones Chile',
        'Количество семян' : 20,
        'Источник': 'Подарок немцев'
    },
    {
        'index':16,
        'Род':'GASTERIA',
        'Вид': 'ellaphieae',
        'Количество семян' : 32,
        'Номер в каталоге': 1214.015,
        'Источник': 'Кактус клуб'
    },
    {
        'index':17,
        'Род':'AUSTROCACTUS',
        'Вид': 'caput-medusae',
        'Количество семян' : 2,
        'Источник': 'Сайт Адениум Дома'
    },
    {
        'index':18,
        'Род':'AGAVE',
        'Вид': 'potatorum v verschaffeltii',
        'Количество семян' : 2,
        'Источник': 'Сайт Адениум Дома'
    },
    {
        'index':19,
        'Род':'AGAVE',
        'Вид': 'parrasana',
        'Количество семян' : 3,
        'Источник': 'Сайт Адениум Дома'
    },
    {
        'index':20,
        'Род':'AGAVE',
        'Вид': 'macroacantha',
        'Количество семян' : 3,
        'Источник': 'Сайт Адениум Дома'
    },
    {
        'index':21,
        'Род':'AGAVE',
        'Вид': 'MIX',
        'Количество семян' : 4,
        'Источник': 'Сайт Адениум Дома'
    },
]

# %%
df = pd.DataFrame(data)
df.index = df['index']
df = df[['Род', 'Вид', 'Место произрастания', 'Количество семян', 'Номер в каталоге' ,'Источник']]

# %%
df
# Out:
#                        Род                         Вид  \
# index
# 1              ASTROPHYTUM                crassispinum
# 2             AUSTROCACTUS                 patagonicus
# 3             AUSTROCACTUS                  subandinus
# 4             ECHINOCACTUS                    grusonii
# 5             ECHINOCACTUS             horizontalonius
# 6                  FRAILEA                 asterioides
# 7      ECHINOFOSSULOCACTUS               multicostatus
# 8            TURBINICARPUS                     alonsoi
# 9           GYMNOCALYCIUM                   esperanzae
# 10             MAMMILLARIA               blossfeldiana
# 11                 LOBIVIA                famatimensis
# 12                 LOBIVIA                     jajoana
# 13             MAMMILLARIA        saboae ssp. roczekii
# 14             NEOCHILENIA                heinrichiana
# 15                ERIOSYCE                  curvispina
# 16                GASTERIA                  ellaphieae
# ...

# %% [markdown]
# ### Замачивание с применением Фитоспорина, Цитовита и Циркона

# %%
i = Image('img/start.jpg')

# %%
i
